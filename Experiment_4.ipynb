# %%
from matplotlib import pyplot as pp
y=[4,6,4,5,4,5,4,6,5]
x=[4,4,4,4.5,4.5,4,4]
z=[5,6,5,6,5,6,5,6]
pp.plot(y,'b')
pp.plot(x,'g')
pp.plot(z,'r+')
pp.show()

# %%
from matplotlib import pyplot as pp
x=[1,2,3,4,5]
y=[10,15,5,10,10]
pp.bar(x,y)
pp.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
x=np.array([1,2,3,4])
la=['mca','mba','msw','Mcom']
ex=[0,0,0.3,0]
plt.pie(x,labels=la,explode=ex,startangle=135,shadow=True)
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([5,10,15,20])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([1,2,3,4])
y=np.array([40,30,15,10])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
from PIL import Image
from scipy import ndimage
from matplotlib import pyplot as plt
a=Image.open('car.jpg')
b=np.array(a)
c=ndimage.rotate(b,45,cval=145)
d=Image.fromarray(c)
plt.imshow(d)
plt.show()

# %%
import numpy as np
from PIL import Image
from scipy import ndimage
from matplotlib import pyplot as plt
a=Image.open("car.jpg")
b=np.array(a)
c=ndimage.zoom(b,(2,2,1))
d=Image.fromarray(c)
plt.imshow(d)
plt.show()
