# %%
import pandas as pd
ds={'DEPT':['DCA','DBA','DSW'], 'COURSE':['MCA','MBA','MSW'],'NO. STUDENTS':['24','2','30']}
pd.DataFrame(ds)
# Out:
#   COURSE DEPT NO. STUDENTS
# 0    MCA  DCA           24
# 1    MBA  DBA            2
# 2    MSW  DSW           30

# %%
se=[20,65,48]
pd.Series(se)
# Out:
# 0    20
# 1    65
# 2    48
# dtype: int64

# %%
d=pd.read_csv("list.csv")
print(d.to_string)
# Out:
# <bound method DataFrame.to_string of                        Sl. No.                    State/ UT Abbreviation
# 0                            1               Andhra Pradesh           AP
# 1                            2            Arunachal Pradesh           AR
# 2                            3                        Assam           AS
# 3                            4                        Bihar           BR
# 4                            5                 Chhattisgarh           CG
# 5                            6                          Goa           GA
# 6                            7                      Gujarat           GJ
# 7                            8                      Haryana           HR
# 8                            9             Himachal Pradesh           HP
# 9                           10            Jammu and Kashmir           JK
# 10                          11                    Jharkhand           JH
# ...

# %%
d=pd.read_csv("list.csv")
print(d.head(10))
# Out:
#   Sl. No.          State/ UT Abbreviation
# 0       1     Andhra Pradesh           AP
# 1       2  Arunachal Pradesh           AR
# 2       3              Assam           AS
# 3       4              Bihar           BR
# 4       5       Chhattisgarh           CG
# 5       6                Goa           GA
# 6       7            Gujarat           GJ
# 7       8            Haryana           HR
# 8       9   Himachal Pradesh           HP
# 9      10  Jammu and Kashmir           JK

# %%
print(d.tail(10))
# Out:
#                        Sl. No.                    State/ UT Abbreviation
# 28                          29                    Telangana           TS
# 29                          30  Andaman and Nicobar Islands           AN
# 30                          31                   Chandigarh           CH
# 31                          32       Dadra and Nagar Haveli           DH
# 32                          33                Daman and Diu           DD
# 33                          34                        Delhi           DL
# 34                          35                  Lakshadweep           LD
# 35                          36                  Pondicherry           PY
# 36                         NaN                          NaN          NaN
# 37  www.downloadexcelfiles.com                          NaN          NaN

# %%
import pandas as pd
a=pd.read_csv('glass.csv')
print(a.head(6))
print(a.tail(6))

print("\nMean of K is ",a['K'].mean())
print("\nMedian of K is ",a['K'].median())
print("\nMode of K is ",a['K'].mode().to_string())
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.00     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00     1
# 5  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26     1
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 208  1.51640  14.37  0.0  2.74  72.85  0.00  9.45  0.54  0.0     7
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# Mean of K is  0.49705607476635494
#
# ...

# %%
import pandas as pd
a=pd.read_csv('glass.csv')
print(a.duplicated().to_string())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39      True
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
import pandas as pd
a=pd.read_csv('glass.csv')
print(a.info())
print(a.loc[0])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
# RI      214 non-null float64
# Na      214 non-null float64
# Mg      214 non-null float64
# Al      214 non-null float64
# Si      214 non-null float64
# K       214 non-null float64
# Ca      214 non-null float64
# Ba      214 non-null float64
# Fe      214 non-null float64
# Type    214 non-null int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB
# None
# RI       1.52101
# Na      13.64000
# Mg       4.49000
# Al       1.10000
# Si      71.78000
# K        0.06000
# Ca       8.75000
# Ba       0.00000
# Fe       0.00000
# Type     1.00000
# Name: 0, dtype: float64

# %%
import pandas as pd
a=pd.read_csv('glass.csv')
print(a.dropna())
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00     1
# 5    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26     1
# 6    1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.00  0.00     1
# 7    1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.00  0.00     1
# 8    1.51918  14.04  3.58  1.37  72.08  0.56  8.30  0.00  0.00     1
# 9    1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.00  0.11     1
# 10   1.51571  12.72  3.46  1.56  73.20  0.67  8.09  0.00  0.24     1
# 11   1.51763  12.80  3.66  1.27  73.01  0.60  8.56  0.00  0.00     1
# 12   1.51589  12.88  3.43  1.40  73.28  0.69  8.05  0.00  0.24     1
# ...
